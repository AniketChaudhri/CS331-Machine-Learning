# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as mvn

# %%
df = pd.read_csv('faithful.csv')
df= df.drop('Unnamed: 0',axis=1)

# %%
df.columns = ['eruptions','waiting']

# %%
plt.scatter(df["eruptions"],df['waiting'], c = 'blue', marker = 'o',label = 'Displaying points on a graph'  )
plt.show()

# %%
def calculatez(mean, covariance):
    x, y = np.mgrid[-1:2:.05, -1:2:.05]
    data = np.column_stack([x.flat, y.flat])
    z = mvn.pdf(data,mean, covariance).reshape(x.shape)
    return x,y,z

# %%
def Estep(X,mean,covariance,coeff):
    K=mean.shape[0]
    gamma = np.zeros(shape=(X.shape[0], K))
    for k in range(K):
        gamma[:, k] = mvn.pdf(X, mean[k], covariance[k]) * coeff[k]
    gamma = gamma/np.sum(gamma, axis=1, keepdims=True)
    return gamma

# %%
def Mstep(X,gamma):
    K = gamma.shape[1]
    Nk = np.sum(gamma, axis=0)
    pi = Nk / np.sum(gamma)
    mean = np.sum(gamma[:, :, np.newaxis] * X[:, np.newaxis, :], axis=1) / Nk
    diff = X[:, :] - mean
    print(diff.shape)
    print(gamma.shape)
    variance = np.sum(gamma[:, :, np.newaxis, np.newaxis] * diff[:, :, np.newaxis, :] * diff[:, :, :, np.newaxis].T, axis=1) / Nk

    return pi,mean, variance

# %%
X=df.to_numpy()
K=2
N, D = X.shape
mu = X[np.random.choice(N, size=K, replace=False), :]
pi = np.ones(shape=(K), dtype=np.float64)/K
sigma = np.zeros(shape=(K, D, D), dtype=np.float64)
for d in range(D):
    sigma[:, d, d] = np.var(X[:, d])/10
gamma = Estep(X, mu, sigma, pi)

# %%
Nk = np.sum(gamma, axis=0)
mean = np.sum(gamma[:, :, np.newaxis] * X[:, np.newaxis, :], axis=1) / Nk
diff = X[:, :] - mean

# %%
variance = np.sum(gamma[:, :] * ((diff[:, :]).T @ diff[:, :]), axis=1) / Nk
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8388/3155616862.py in <module>
# ----> 1 variance = np.sum((gamma[:, :]) @ ((diff[:, :]).T @ diff[:, :]), axis=1) / Nk
#
# ValueError: operands could not be broadcast together with shapes (272,) (2,)

# %%
variance
# Out:
# array([[   18.57267771,   907.9884316 ],
#        [  348.38996947, 17511.2674851 ],
#        [   18.59872978,   909.29991478],
#        [   94.39857197,  4725.12753679],
#        [   18.57120826,   907.91445839],
#        [  196.92514638,  9886.40127188],
#        [   18.57120174,   907.91413028],
#        [   18.57130941,   907.91955023],
#        [  353.63916189, 17775.51623351],
#        [   18.57121356,   907.91472524],
#        [  347.53138679, 17468.04571318],
#        [   18.57126926,   907.917529  ],
#        [   18.57162052,   907.93521164],
#        [  357.07334905, 17948.39609517],
#        [   18.5712121 ,   907.91465152],
#        [  346.80371929, 17431.41432076],
#        [  209.84127064, 10536.60979878],
#        [   18.57120612,   907.91435062],
#        [  355.25035975, 17856.62528506],
#        [   18.5714367 ,   907.92595838],
#        [  354.94710166, 17841.35901838],
#        [  357.07334905, 17948.39609517],
#        [   18.57468249,   908.08935396],
# ...

# %%
def logLikelihood(X,gamma,variance,mean,pi):
    N, K = gamma.shape
    mvn = multivariate_normal(mean=mean, cov=variance, allow_singular=True)
    log_probs = mvn.logpdf(X[:, np.newaxis, :])
    log_likelihoods = log_probs + np.log(pi) + np.log(gamma[:, :, np.newaxis])
    llh = np.sum(log_likelihoods)
    return llh

# %%
def EM(df,K,delta=0.001):
    X=df.to_numpy()
    N, D = X.shape
    mu = X[np.random.choice(N, size=K, replace=False), :]
    pi = np.ones(shape=(K), dtype=np.float64)/K
    sigma = np.zeros(shape=(K, D, D), dtype=np.float64)
    for d in range(D):
        sigma[:, d, d] = np.var(X[:, d])/10
        
    cur_llh = np.float(1e9)
    prev_llh=0.0
    iter=0
    while(abs(cur_llh-prev_llh)>delta):
        gamma = Estep(X, mu, sigma, pi)
        mu, sigma, pi = Mstep(X, gamma)
        
        prev_llh = cur_llh
        cur_llh = logLikelihood(X, gamma, sigma, mu, pi)

        labels = np.argmax(gamma, axis=1)
        iter=iter+1
        plt.figure()
        c=['blue','red','black']

        plt.scatter(faithful_df['eruptions'], faithful_df['waiting'],c=gamma[:,1],cmap='cool')
        for i in range(0,K):
            x,y,z=generateZ(mu[i],sigma[i])
            plt.contour(x, y, z,colors=c[i])
        plt.show()


    return mu, sigma, pi, gamma, labels

# %%
mu, sigma, pi, gamma, labels=EM(df,2)
# Out:
# (272, 2)
# (272, 2)
# C:\Users\Somesh\AppData\Local\Temp/ipykernel_8388/1333549942.py:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cur_llh = np.float(1e9)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8388/2619047883.py in <module>
# ----> 1 mu, sigma, pi, gamma, labels=EM(df,2)
#
# ~\AppData\Local\Temp/ipykernel_8388/1333549942.py in EM(df, K, delta)
#      13     while(abs(cur_llh-prev_llh)>delta):
#      14         gamma = Estep(X, mu, sigma, pi)
# ---> 15         mu, sigma, pi = Mstep(X, gamma)
#      16
# ...
